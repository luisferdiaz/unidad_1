# %%
import pandas as pd

# %%
# Load of all .csv
df_ubereats_centro = pd.read_csv(r'csv/ubereats-pizza-centro.csv')
df_ubereats_alamos = pd.read_csv(r'csv/ubereats-pizza-alamos.csv')
df_ubereats_juriquilla = pd.read_csv(r'csv/ubereats-pizza-juriquilla.csv')
df_ubereats_milenio = pd.read_csv(r'csv/ubereats-pizza-milenio.csv')
df_ubereats_refugio = pd.read_csv(r'csv/ubereats-pizza-refugio.csv')

df_ubereats_balvanera = pd.read_csv(r'csv/ubereats-pizza-balvanera.csv')
df_ubereats_campanario = pd.read_csv(r'csv/ubereats-pizza-campanario.csv')
df_ubereats_cerritocolorado = pd.read_csv(r'csv/ubereats-pizza-cerritocolorado.csv')
df_ubereats_cimatario = pd.read_csv(r'csv/ubereats-pizza-cimatario.csv')
df_ubereats_el_pueblito = pd.read_csv(r'csv/ubereats-pizza-el-pueblito.csv')

df_rappi_centro = pd.read_csv(r'csv/rappi-pizza-centro.csv')
df_rappi_alamos = pd.read_csv(r'csv/rappi-pizza-alamos.csv')
df_rappi_juriquilla = pd.read_csv(r'csv/rappi-pizza-juriquilla.csv')
df_rappi_milenio = pd.read_csv(r'csv/rappi-pizza-milenio.csv')
df_rappi_refugio = pd.read_csv(r'csv/rappi-pizza-refugio.csv')

df_rappi_balvanera = pd.read_csv(r'csv/rappi-pizza-balvanera.csv')
df_rappi_campanario = pd.read_csv(r'csv/rappi-pizza-campanario.csv')
df_rappi_cerritocolorado = pd.read_csv(r'csv/rappi-pizza-cerritocolorado.csv')
df_rappi_cimatario = pd.read_csv(r'csv/rappi-pizza-cimatario.csv')
df_rappi_el_pueblito = pd.read_csv(r'csv/rappi-pizza-el-pueblito.csv')

df_centro = pd.concat([df_ubereats_centro, df_rappi_centro], ignore_index = True)
df_alamos = pd.concat([df_ubereats_alamos, df_rappi_alamos], ignore_index = True)
df_juriquilla = pd.concat([df_ubereats_juriquilla, df_rappi_juriquilla], ignore_index = True)
df_milenio = pd.concat([df_ubereats_milenio, df_rappi_milenio], ignore_index = True)
df_refugio = pd.concat([df_ubereats_refugio, df_rappi_refugio], ignore_index = True)
df_balvanera = pd.concat([df_ubereats_balvanera, df_rappi_balvanera], ignore_index = True)
df_campanario = pd.concat([df_ubereats_campanario, df_rappi_campanario], ignore_index = True)
df_cerritocolorado = pd.concat([df_ubereats_cerritocolorado, df_rappi_cerritocolorado], ignore_index = True)
df_cimatario = pd.concat([df_ubereats_cimatario, df_rappi_cimatario], ignore_index = True)
df_el_pueblito = pd.concat([df_ubereats_el_pueblito, df_rappi_el_pueblito], ignore_index = True)

# %%
# Remove MX$ from price-food
df_centro['price-food'] = df_centro['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_alamos['price-food'] = df_alamos['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_juriquilla['price-food'] = df_juriquilla['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_milenio['price-food'] = df_milenio['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_refugio['price-food'] = df_refugio['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_balvanera['price-food'] = df_balvanera['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_campanario['price-food'] = df_campanario['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_cerritocolorado['price-food'] = df_cerritocolorado['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_cimatario['price-food'] = df_cimatario['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)
df_el_pueblito['price-food'] = df_el_pueblito['price-food'].apply(lambda x: (float(x[3:] if x[0] == 'M' else x[1:]) if not isinstance(x, int) else float(x)) if not isinstance(x, float) else x)

# %%
#Loc all 'pizzas'
dfPizzas_centro = df_centro[df_centro['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_centro.reset_index(drop=True, inplace=True)
dfPizzas_alamos = df_alamos[df_alamos['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_alamos.reset_index(drop=True, inplace=True)
dfPizzas_juriquilla = df_juriquilla[df_juriquilla['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_juriquilla.reset_index(drop=True, inplace=True)
dfPizzas_milenio = df_milenio[df_milenio['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_milenio.reset_index(drop=True, inplace=True)
dfPizzas_refugio = df_refugio[df_refugio['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_refugio.reset_index(drop=True, inplace=True)
dfPizzas_balvanera = df_balvanera[df_balvanera['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_balvanera.reset_index(drop=True, inplace=True)
dfPizzas_campanario = df_campanario[df_campanario['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_campanario.reset_index(drop=True, inplace=True)
dfPizzas_cerritocolorado = df_cerritocolorado[df_cerritocolorado['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_cerritocolorado.reset_index(drop=True, inplace=True)
dfPizzas_cimatario = df_cimatario[df_cimatario['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_cimatario.reset_index(drop=True, inplace=True)
dfPizzas_el_pueblito = df_el_pueblito[df_el_pueblito['name-food'].str.contains("pizza", na=False, case=False)]
dfPizzas_el_pueblito.reset_index(drop=True, inplace=True)

# %%
#Medians
colonies = ['Centro', 'Alamos', 'Juriquilla', 'Milenio III','Refugio','Balvanera','Campanario','Cerrito Colorado','El Cimatario','El Pueblito']
medians = [dfPizzas_centro['price-food'].median(),dfPizzas_alamos['price-food'].median(),dfPizzas_juriquilla['price-food'].median(),
           dfPizzas_milenio['price-food'].median(), dfPizzas_refugio['price-food'].median(), dfPizzas_balvanera['price-food'].median(),
           dfPizzas_campanario['price-food'].median(), dfPizzas_cerritocolorado['price-food'].median(), dfPizzas_cimatario['price-food'].median(),
           dfPizzas_el_pueblito['price-food'].median()
          ]

# %%
import matplotlib.pyplot as plt

# %%
print(medians)
plt.barh(colonies,medians,color=['royalblue', 'g', 'r', 'c', 'm', 'y','sandybrown', 'hotpink', 'greenyellow' ,'deepskyblue'])
plt.title('Precio promedio de pizzas')
plt.xlabel('Precio promedio')
plt.ylabel('Colonias')
plt.show()
# Out:
# [179.0, 175.0, 170.0, 179.0, 195.0, 165.0, 180.0, 142.0, 175.0, 165.0]

# %%
#dfPizzas_centro.loc[:,['name','rating','evals','name-food','price-food']]
dfPizzas_centro['colonia'] = 'Centro'
dfPizzas_alamos['colonia'] = 'Alamos'
dfPizzas_juriquilla['colonia'] = 'Juriquilla'
dfPizzas_milenio['colonia'] = 'Milenio III'
dfPizzas_refugio['colonia'] = 'El Refugio'
dfPizzas_balvanera['colonia'] = 'Balvanera'
dfPizzas_campanario['colonia'] = 'El campanario'
dfPizzas_cerritocolorado['colonia'] = 'Cerrito Colorado'
dfPizzas_cimatario['colonia'] = 'El Cimatario'
dfPizzas_el_pueblito['colonia'] = 'El Pueblito'
# Out:
# /home/luis/unidad_1/unidad_1_env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/luis/unidad_1/unidad_1_env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/luis/unidad_1/unidad_1_env/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
#modePizzaCentro = dfPizzas_centro.loc[dfPizzas_centro['name-food'] == dfPizzas_centro['name-food'].mode()[0]]
#modePizzaCentroPrice = dfPizzas_centro.loc[dfPizzas_centro['price-food'] == dfPizzas_centro['price-food'].mode()[0]]
#modePizzaCentro.loc[:,['name','name-food','price-food']]
#modePizzaCentroPrice.loc[:,['name','name-food','price-food']]
frames = [dfPizzas_centro,dfPizzas_alamos, dfPizzas_juriquilla, dfPizzas_milenio, dfPizzas_refugio, dfPizzas_balvanera, 
          dfPizzas_campanario,
          dfPizzas_cerritocolorado,
          dfPizzas_cimatario,
          dfPizzas_el_pueblito
         ]
df = pd.concat(frames, ignore_index=True)

# %%
modePizzasFood = df.loc[df['name-food'] == df['name-food'].mode()[0]]
modePizzasFood.reset_index(drop=True, inplace=True)

duplicatesValues = df.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValues.sort_values(ascending = False)
#duplicatesValues

#modePizzasFood.loc[:,['colonia','name','name-food','price-food']]
#modePizzasPrice = df.loc[df['price-food'] == df['price-food'].mode()[0]]
#modePizzasPrice.reset_index(drop=True, inplace=True)

#dfPizzas_centro.loc[dfPizzas_centro['name-food'] == modePizzasFood['name-food'][1]].loc[dfPizzas_centro['price-food'] == modePizzasPrice['price-food'][1]]
#len(dfPizzas_centro.loc[dfPizzas_centro['name-food'] == modePizzasFood['name-food'][1]].index)

#dfPizzas_centro.loc[:,['name','name-food','price-food']]
# Out:
# name-food
# Pizza Hawaiana              222
# Pizza Vegetariana           144
# Pizza Mexicana              134
# Pizza Pepperoni             124
# Pizza Margarita             120
#                            ...
# Pizza de Chilorio             1
# Pizza Rosarito                1
# Pizza de Cochinita Pibil      1
# Pizza de Flaming Hot          1
# Pizza de Pastor Familiar      1
# Length: 1973, dtype: int64

# %%
restaurants = df.pivot_table(index = ['name'], aggfunc='size')
print(len(restaurants))
# Out:
# 349

# %%
pizzaHawaiana = 222
pizzaVegetariana = 144
pizzaMexicana = 134
threePizzas = 108

#plt.figure(figsize=(8, 8))
plt.pie([pizzaHawaiana, len(restaurants) - pizzaHawaiana],labels = [ "{:.2f}".format(pizzaHawaiana * 100 / len(restaurants)) + '%', "{:.2f}".format((len(restaurants) - pizzaHawaiana) * 100 / len(restaurants)) + '%'],colors=['hotpink', 'sandybrown'] ,shadow = True, startangle = 45, )
plt.legend(title =  "Incluye Pizza Hawaiana")
plt.show()

#plt.figure(figsize=(8, 8))
plt.pie([pizzaVegetariana, len(restaurants) - pizzaVegetariana],labels = [ "{:.2f}".format(pizzaVegetariana * 100 / len(restaurants)) + '%', "{:.2f}".format((len(restaurants) - pizzaVegetariana) * 100 / len(restaurants)) + '%'], colors = ['c', 'm'], shadow = True, startangle = 45)
plt.legend(title =  "Incluye Pizza Vegetariana")
plt.show()

#plt.figure(figsize=(8, 8))
plt.pie([pizzaMexicana, len(restaurants) - pizzaMexicana],labels = [ "{:.2f}".format(pizzaMexicana * 100 / len(restaurants)) + '%', "{:.2f}".format((len(restaurants) - pizzaMexicana) * 100 / len(restaurants)) + '%'], colors = ['greenyellow' ,'deepskyblue'], shadow = True, startangle = 45)
plt.legend(title =  "Incluye Pizza Mexicana")
plt.show()

plt.figure(figsize=(8, 8))
plt.pie([threePizzas, len(restaurants) - threePizzas],labels = [ "{:.2f}".format(threePizzas * 100 / len(restaurants)) + '%', "{:.2f}".format((len(restaurants) - threePizzas) * 100 / len(restaurants)) + '%'], shadow = True, startangle = 45)
plt.legend(title =  "Incluye las 3 pizzas")
plt.show()

# %%
centro1 = dfPizzas_centro.loc[dfPizzas_centro['name-food'] == 'Pizza Hawaiana']
centro2 = dfPizzas_centro.loc[dfPizzas_centro['name-food'] == 'Pizza Vegetariana']
centro3 = dfPizzas_centro.loc[dfPizzas_centro['name-food'] == 'Pizza Mexicana']
c1 = list(centro1['name'])
c2 = list(centro2['name'])
c3 = list(centro3['name'])

tipicMenuCentro = []
for i in c1: 
    if i in c2 and i in c3: tipicMenuCentro.append(i)
alamos1 = dfPizzas_alamos.loc[dfPizzas_alamos['name-food'] == 'Pizza Hawaiana']
alamos2 = dfPizzas_alamos.loc[dfPizzas_alamos['name-food'] == 'Pizza Vegetariana']
alamos3 = dfPizzas_alamos.loc[dfPizzas_alamos['name-food'] == 'Pizza Mexicana']

a1 = list(alamos1['name'])
a2 = list(alamos2['name'])
a3 = list(alamos3['name'])

tipicMenuAlamos = []
for i in a1:
    if i in a2 and i in a3: tipicMenuAlamos.append(i)

# %%
juriquilla1 = dfPizzas_juriquilla.loc[dfPizzas_juriquilla['name-food'] == 'Pizza Hawaiana']
juriquilla2 = dfPizzas_juriquilla.loc[dfPizzas_juriquilla['name-food'] == 'Pizza Vegetariana']
juriquilla3 = dfPizzas_juriquilla.loc[dfPizzas_juriquilla['name-food'] == 'Pizza Mexicana']
j1 = list(juriquilla1['name'])
j2 = list(juriquilla2['name'])
j3 = list(juriquilla3['name'])
tipicMenuJuriquilla = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenuJuriquilla.append(i)

# %%
milenio1 = dfPizzas_milenio.loc[dfPizzas_milenio['name-food'] == 'Pizza Hawaiana']
milenio2 = dfPizzas_milenio.loc[dfPizzas_milenio['name-food'] == 'Pizza Vegetariana']
milenio3 = dfPizzas_milenio.loc[dfPizzas_milenio['name-food'] == 'Pizza Mexicana']
j1 = list(milenio1['name'])
j2 = list(milenio2['name'])
j3 = list(milenio3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenuMilenio = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenuMilenio.append(i)
# Out:
# 40
# 28
# 28

# %%
refugio1 = dfPizzas_refugio.loc[dfPizzas_refugio['name-food'] == 'Pizza Hawaiana']
refugio2 = dfPizzas_refugio.loc[dfPizzas_refugio['name-food'] == 'Pizza Vegetariana']
refugio3 = dfPizzas_refugio.loc[dfPizzas_refugio['name-food'] == 'Pizza Mexicana']
j1 = list(refugio1['name'])
j2 = list(refugio2['name'])
j3 = list(refugio3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenurefugio = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenurefugio.append(i)
# Out:
# 6
# 3
# 3

# %%
balvanera1 = dfPizzas_balvanera.loc[dfPizzas_balvanera['name-food'] == 'Pizza Hawaiana']
balvanera2 = dfPizzas_balvanera.loc[dfPizzas_balvanera['name-food'] == 'Pizza Vegetariana']
balvanera3 = dfPizzas_balvanera.loc[dfPizzas_balvanera['name-food'] == 'Pizza Mexicana']
j1 = list(balvanera1['name'])
j2 = list(balvanera2['name'])
j3 = list(balvanera3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenubalvanera = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenubalvanera.append(i)
# Out:
# 5
# 2
# 1

# %%
campanario1 = dfPizzas_campanario.loc[dfPizzas_campanario['name-food'] == 'Pizza Hawaiana']
campanario2 = dfPizzas_campanario.loc[dfPizzas_campanario['name-food'] == 'Pizza Vegetariana']
campanario3 = dfPizzas_campanario.loc[dfPizzas_campanario['name-food'] == 'Pizza Mexicana']
j1 = list(campanario1['name'])
j2 = list(campanario2['name'])
j3 = list(campanario3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenucampanario = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenucampanario.append(i)
# Out:
# 19
# 9
# 12

# %%
cerritocolorado1 = dfPizzas_cerritocolorado.loc[dfPizzas_cerritocolorado['name-food'] == 'Pizza Hawaiana']
cerritocolorado2 = dfPizzas_cerritocolorado.loc[dfPizzas_cerritocolorado['name-food'] == 'Pizza Vegetariana']
cerritocolorado3 = dfPizzas_cerritocolorado.loc[dfPizzas_cerritocolorado['name-food'] == 'Pizza Mexicana']
j1 = list(cerritocolorado1['name'])
j2 = list(cerritocolorado2['name'])
j3 = list(cerritocolorado3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenucerritocolorado = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenucerritocolorado.append(i)
# Out:
# 12
# 6
# 8

# %%
cimatario1 = dfPizzas_cimatario.loc[dfPizzas_cimatario['name-food'] == 'Pizza Hawaiana']
cimatario2 = dfPizzas_cimatario.loc[dfPizzas_cimatario['name-food'] == 'Pizza Vegetariana']
cimatario3 = dfPizzas_cimatario.loc[dfPizzas_cimatario['name-food'] == 'Pizza Mexicana']
j1 = list(cimatario1['name'])
j2 = list(cimatario2['name'])
j3 = list(cimatario3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenucimatario = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenucimatario.append(i)
# Out:
# 45
# 30
# 23

# %%
el_pueblito1 = dfPizzas_el_pueblito.loc[dfPizzas_el_pueblito['name-food'] == 'Pizza Hawaiana']
el_pueblito2 = dfPizzas_el_pueblito.loc[dfPizzas_el_pueblito['name-food'] == 'Pizza Vegetariana']
el_pueblito3 = dfPizzas_el_pueblito.loc[dfPizzas_el_pueblito['name-food'] == 'Pizza Mexicana']
j1 = list(el_pueblito1['name'])
j2 = list(el_pueblito2['name'])
j3 = list(el_pueblito3['name'])
print(len(j1))
print(len(j2))
print(len(j3))
tipicMenuel_pueblito = []
for i in j1:
    if i in j2 and i in j3:
        tipicMenuel_pueblito.append(i)
# Out:
# 15
# 12
# 12

# %%
#print(len(tipicMenuCentro))
#print(len(tipicMenuAlamos))
#print(len(tipicMenuJuriquilla))
#print(len(tipicMenuMilenio))
#print(len(tipicMenurefugio))
#print(len(tipicMenubalvanera))
#print(len(tipicMenucampanario))
#print(len(tipicMenucerritocolorado))
#print(len(tipicMenucimatario))
#print(len(tipicMenuel_pueblito))

#sumTipicMenu = len(tipicMenuCentro) + len(tipicMenuAlamos) + len(tipicMenuJuriquilla) + len(tipicMenuMilenio) +len(tipicMenurefugio) + len(tipicMenubalvanera) + len(tipicMenucampanario) + len(tipicMenucerritocolorado) + len(tipicMenucimatario) + len(tipicMenuel_pueblito)

colonies = ['Centro', 'Alamos', 'Juriquilla', 'Milenio III','Refugio','Balvanera','Campanario','Cerrito Colorado','El Cimatario','El Pueblito']
tipicMenusColonies = [len(tipicMenuCentro),len(tipicMenuAlamos),len(tipicMenuJuriquilla),len(tipicMenuMilenio),len(tipicMenurefugio),len(tipicMenubalvanera),len(tipicMenucampanario),len(tipicMenucerritocolorado),len(tipicMenucimatario),len(tipicMenuel_pueblito)]

# %%
plt.figure(figsize=(8, 8))
plt.barh(colonies,tipicMenusColonies,color=['royalblue', 'g', 'r', 'c', 'm', 'y','sandybrown', 'hotpink', 'greenyellow' ,'deepskyblue'])
plt.title('Restaurantes que incluyen el Menú típico')
plt.xlabel('Número de restaurantes')
plt.ylabel('Colonias')
plt.show()

# %%
preciosPorColoniasAltos = []
preciosPorColoniasBajos = []
ratingPorColonia = []

# %%
#Restaurantes por colonia
#centro dfPizzas_centro

sortAscPricecentro = dfPizzas_centro.sort_values(by = ['price-food'], ascending=False)
sortAscPricecentro.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricecentro['name'][0]}")
print(f"Precio Alto: {sortAscPricecentro['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricecentro['price-food'][0])

print(f"Precio bajo: {sortAscPricecentro['name'][len(sortAscPricecentro.index) - 1]}")
print(f"Precio bajo: {sortAscPricecentro['price-food'][len(sortAscPricecentro.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricecentro['price-food'][len(sortAscPricecentro.index) - 1])

sortAscRating = dfPizzas_centro.sort_values(by = ['rating'], ascending = False)

sortAscRating.loc[:,['name','name-food','rating']]
#sortAscRating.reset_index(drop=True, inplace=True)

#ratingPorColonia.append(sortAscRating['rating'])


#duplicatesValuescentro = dfPizzas_centro.pivot_table(index = ['name-food'], aggfunc='size')

#duplicatesValuescentro.sort_values(ascending = False)
# Out:
# Precio Alto: "Happy Box" Cajas de Alitas y Snaks
# Precio Alto: 449.0
# Precio bajo: Lecaroz (QUERETARO)
# Precio bajo: 15.0
#                       name                      name-food  rating
# 298         Rayuela Pizzas                Pizza Al Pastor     4.9
# 351         Rayuela Pizzas                Pizza Fugazzeta     4.9
# 873         Rayuela Pizzas                  Pizza Rayuela     4.9
# 896         Rayuela Pizzas                Pizza Pescadora     4.9
# 692         Rayuela Pizzas                Pizza Al Pastor     4.9
# ...                    ...                            ...     ...
# 1410  La Piccola Trattoria      Pizza Salsiccia E Burrata     NaN
# 1412         Santa Fortuna          Pizza Pollo Arrabiata     NaN
# 1413       Mamba Pizza Co.  Pizza Familiar Mamba Tropical     NaN
# 1414  La Piccola Trattoria              Pizza Fiordilatte     NaN
# 1416    Trattoria La Nonna              Pizza Vegetariana     NaN
#
# [1418 rows x 3 columns]

# %%
#Restaurantes por colonia
#alamos dfPizzas_alamos

sortAscPricealamos = dfPizzas_alamos.sort_values(by = ['price-food'], ascending=False)
sortAscPricealamos.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricealamos['name'][0]}")
print(f"Precio Alto: {sortAscPricealamos['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricealamos['price-food'][0])

print(f"Precio bajo: {sortAscPricealamos['name'][len(sortAscPricealamos.index) - 1]}")
print(f"Precio bajo: {sortAscPricealamos['price-food'][len(sortAscPricealamos.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricealamos['price-food'][len(sortAscPricealamos.index) - 1])

sortAscRating = dfPizzas_alamos.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)
sortAscRating.loc[:,['name','name-food','rating']]
#ratingPorColonia.append(sortAscRating['rating'])


#duplicatesValuesalamos = dfPizzas_alamos.pivot_table(index = ['name-food'], aggfunc='size')

#duplicatesValuesalamos.sort_values(ascending = False)

#sortAscPricealamos['price-food']
# Out:
# Precio Alto: "Happy Box" Cajas de Alitas y Snaks
# Precio Alto: 449.0
# Precio bajo: Lecaroz (QUERETARO)
# Precio bajo: 15.0
#                                name                       name-food  rating
# 0    La Piccola Trattoria Querétaro               pizza fiordilatte     9.0
# 1    La Piccola Trattoria Querétaro                pizza margherita     9.0
# 2    La Piccola Trattoria Querétaro                 pizza pepperoni     9.0
# 3    La Piccola Trattoria Querétaro  pizza diavola-pizza margherita     9.0
# 4    La Piccola Trattoria Querétaro                pizza berlusconi     9.0
# ..                              ...                             ...     ...
# 987              Trattoria La Nonna                   Pizza Salmone     NaN
# 988              Trattoria La Nonna             Arrachera Pizzaiola     NaN
# 989                       lynchburg                 Pizza de Quesos     NaN
# 990               La Vieja Varsovia              Pizza Mediterránea     NaN
# ...

# %%
#Restaurantes por colonia
#juriquilla dfPizzas_juriquilla

sortAscPricejuriquilla = dfPizzas_juriquilla.sort_values(by = ['price-food'], ascending=False)
sortAscPricejuriquilla.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricejuriquilla['name'][0]}")
print(f"Precio Alto: {sortAscPricejuriquilla['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricejuriquilla['price-food'][0])

print(f"Precio bajo: {sortAscPricejuriquilla['name'][len(sortAscPricejuriquilla.index) - 1]}")
print(f"Precio bajo: {sortAscPricejuriquilla['price-food'][len(sortAscPricejuriquilla.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricejuriquilla['price-food'][len(sortAscPricejuriquilla.index) - 1])

sortAscRating = dfPizzas_juriquilla.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


sortAscPricejuriquilla
#duplicatesValuesjuriquilla = dfPizzas_juriquilla.pivot_table(index = ['name-food'], aggfunc='size')

#duplicatesValuesjuriquilla.sort_values(ascending = False)
# Out:
# Precio Alto: Wohoo! Desayunos Sorpresa
# Precio Alto: 860.0
# Precio bajo: El Hornero
# Precio bajo: nan
#     web-scraper-order                              web-scraper-start-url  \
# 0     1616631486-3279  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 1     1616631925-6041  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 2     1616631925-6045  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 3     1616631950-6169  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 4     1616632057-6597  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# ..                ...                                                ...
# 595   1616631682-4082  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 596   1616631821-5517  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 597   1616631821-5506  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 598   1616631618-3783  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# ...

# %%
#Restaurantes por colonia
#milenio dfPizzas_milenio

sortAscPricemilenio = dfPizzas_milenio.sort_values(by = ['price-food'], ascending=False)
sortAscPricemilenio.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricemilenio['name'][0]}")
print(f"Precio Alto: {sortAscPricemilenio['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricemilenio['price-food'][0])

print(f"Precio bajo: {sortAscPricemilenio['name'][len(sortAscPricemilenio.index) - 1]}")
print(f"Precio bajo: {sortAscPricemilenio['price-food'][len(sortAscPricemilenio.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricemilenio['price-food'][len(sortAscPricemilenio.index) - 1])

sortAscRating = dfPizzas_milenio.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


duplicatesValuesmilenio = dfPizzas_milenio.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValuesmilenio.sort_values(ascending = False)

sortAscRating
# Out:
# Precio Alto: "Happy Box" Cajas de Alitas y Snaks
# Precio Alto: 449.0
# Precio bajo: iL Forno Pizza.
# Precio bajo: nan
#      web-scraper-order                              web-scraper-start-url  \
# 0      1616633251-3416  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 1      1616633373-4202  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 2      1616634838-9068  https://www.rappi.com.mx/restaurantes/category...
# 3      1616633272-3597  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 4      1616634838-9067  https://www.rappi.com.mx/restaurantes/category...
# ...                ...                                                ...
# 1072   1616634513-7896  https://www.rappi.com.mx/restaurantes/category...
# 1073   1616634474-7742  https://www.rappi.com.mx/restaurantes/category...
# 1074   1616634532-7981  https://www.rappi.com.mx/restaurantes/category...
# 1075   1616634732-8634  https://www.rappi.com.mx/restaurantes/category...
# ...

# %%
#Restaurantes por colonia
#refugio dfPizzas_refugio

sortAscPricerefugio = dfPizzas_refugio.sort_values(by = ['price-food'], ascending=False)
sortAscPricerefugio.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricerefugio['name'][0]}")
print(f"Precio Alto: {sortAscPricerefugio['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricerefugio['price-food'][0])

print(f"Precio bajo: {sortAscPricerefugio['name'][len(sortAscPricerefugio.index) - 1]}")
print(f"Precio bajo: {sortAscPricerefugio['price-food'][len(sortAscPricerefugio.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricerefugio['price-food'][len(sortAscPricerefugio.index) - 1])

#sortAscRating = dfPizzas_refugio.sort_values(by = ['rating'], ascending = False)
#sortAscRating.reset_index(drop=True, inplace=True)

#ratingPorColonia.append(sortAscRating['rating'])
sortAscPricerefugio

#duplicatesValuesrefugio = dfPizzas_refugio.pivot_table(index = ['name-food'], aggfunc='size')

#duplicatesValuesrefugio.sort_values(ascending = False)
# Out:
# Precio Alto: Mangiare
# Precio Alto: 400.0
# Precio bajo: iL Forno Pizza.
# Precio bajo: nan
#     web-scraper-order                              web-scraper-start-url  \
# 0     1616632549-5585  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# 1     1616632541-5524  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# 2     1616632541-5501  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# 3     1616634087-7925  https://www.rappi.com.mx/restaurantes/category...
# 4     1616632541-5525  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# ..                ...                                                ...
# 302   1616632603-6049  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# 303   1616632532-5477  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# 304   1616632557-5634  https://www.ubereats.com/mx/search?ps=1&q=pizz...
# 305   1616634131-8156  https://www.rappi.com.mx/restaurantes/category...
# 306   1616634137-8181  https://www.rappi.com.mx/restaurantes/category...
#
# ...

# %%
#Restaurantes por colonia
#balvanera dfPizzas_balvanera

sortAscPricebalvanera = dfPizzas_balvanera.sort_values(by = ['price-food'], ascending=False)
sortAscPricebalvanera.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricebalvanera['name'][0]}")
print(f"Precio Alto: {sortAscPricebalvanera['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricebalvanera['price-food'][0])

print(f"Precio bajo: {sortAscPricebalvanera['name'][len(sortAscPricebalvanera.index) - 1]}")
print(f"Precio bajo: {sortAscPricebalvanera['price-food'][len(sortAscPricebalvanera.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricebalvanera['price-food'][len(sortAscPricebalvanera.index) - 1])

sortAscRating = dfPizzas_balvanera.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


duplicatesValuesbalvanera = dfPizzas_balvanera.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValuesbalvanera.sort_values(ascending = False)

sortAscPricebalvanera
# Out:
# Precio Alto: Emporio Pizza
# Precio Alto: 320.0
# Precio bajo: Mi Piace Pizza Qro
# Precio bajo: nan
#     web-scraper-order                              web-scraper-start-url  \
# 0     1616626804-5408  https://www.ubereats.com/search?ps=1&q=pizza%2...
# 1     1616626804-5423  https://www.ubereats.com/search?ps=1&q=pizza%2...
# 2     1616626872-6007  https://www.ubereats.com/search?ps=1&q=pizza%2...
# 3      1616630391-236  https://www.rappi.com.mx/restaurantes/category...
# 4     1616626859-5967  https://www.ubereats.com/search?ps=1&q=pizza%2...
# ..                ...                                                ...
# 186   1616626765-5200  https://www.ubereats.com/search?ps=1&q=pizza%2...
# 187   1616626772-5227  https://www.ubereats.com/search?ps=1&q=pizza%2...
# 188   1616626866-5996  https://www.ubereats.com/search?ps=1&q=pizza%2...
# 189   1616626866-5998  https://www.ubereats.com/search?ps=1&q=pizza%2...
# ...

# %%
#Restaurantes por colonia
#campanario dfPizzas_campanario

sortAscPricecampanario = dfPizzas_campanario.sort_values(by = ['price-food'], ascending=False)
sortAscPricecampanario.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricecampanario['name'][0]}")
print(f"Precio Alto: {sortAscPricecampanario['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricecampanario['price-food'][0])

print(f"Precio bajo: {sortAscPricecampanario['name'][len(sortAscPricecampanario.index) - 1]}")
print(f"Precio bajo: {sortAscPricecampanario['price-food'][len(sortAscPricecampanario.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricecampanario['price-food'][len(sortAscPricecampanario.index) - 1])

sortAscRating = dfPizzas_campanario.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


duplicatesValuescampanario = dfPizzas_campanario.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValuescampanario.sort_values(ascending = False)
sortAscPricecampanario
# Out:
# Precio Alto: "Happy Box" Cajas de Alitas y Snaks
# Precio Alto: 449.0
# Precio bajo: Piccolo Pizza
# Precio bajo: nan
#     web-scraper-order                              web-scraper-start-url  \
# 0     1616632615-1336  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 1      1616632450-289  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 2       1616632420-70  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 3       1616632420-46  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 4     1616632654-1682  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# ..                ...                                                ...
# 594   1616632814-2588  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 595    1616632459-345  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 596     1616632410-23  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# 597    1616632481-443  https://www.ubereats.com/search?ps=1&q=Pizza&p...
# ...

# %%
#Restaurantes por colonia
#cerritocolorado dfPizzas_cerritocolorado

sortAscPricecerritocolorado = dfPizzas_cerritocolorado.sort_values(by = ['price-food'], ascending=False)
sortAscPricecerritocolorado.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricecerritocolorado['name'][0]}")
print(f"Precio Alto: {sortAscPricecerritocolorado['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricecerritocolorado['price-food'][0])

print(f"Precio bajo: {sortAscPricecerritocolorado['name'][len(sortAscPricecerritocolorado.index) - 1]}")
print(f"Precio bajo: {sortAscPricecerritocolorado['price-food'][len(sortAscPricecerritocolorado.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricecerritocolorado['price-food'][len(sortAscPricecerritocolorado.index) - 1])

sortAscRating = dfPizzas_cerritocolorado.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


duplicatesValuescerritocolorado = dfPizzas_cerritocolorado.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValuescerritocolorado.sort_values(ascending = False)
sortAscPricecerritocolorado
# Out:
# Precio Alto: Pizzaburger
# Precio Alto: 407.0
# Precio bajo: Pizza & Love
# Precio bajo: nan
#     web-scraper-order                              web-scraper-start-url  \
# 0     1616639194-8178  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 1     1616639194-8177  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 2     1616639040-7871  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 3     1616637555-6175  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 4     1616639194-8176  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# ..                ...                                                ...
# 687   1616637965-6640  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 688   1616637965-6639  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 689   1616637576-6193  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 690   1616637635-6250  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 691   1616637576-6194  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
#
# ...

# %%
#Restaurantes por colonia
#cimatario dfPizzas_cimatario

sortAscPricecimatario = dfPizzas_cimatario.sort_values(by = ['price-food'], ascending=False)
sortAscPricecimatario.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPricecimatario['name'][0]}")
print(f"Precio Alto: {sortAscPricecimatario['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPricecimatario['price-food'][0])

print(f"Precio bajo: {sortAscPricecimatario['name'][len(sortAscPricecimatario.index) - 1]}")
print(f"Precio bajo: {sortAscPricecimatario['price-food'][len(sortAscPricecimatario.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPricecimatario['price-food'][len(sortAscPricecimatario.index) - 1])

sortAscRating = dfPizzas_cimatario.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


duplicatesValuescimatario = dfPizzas_cimatario.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValuescimatario.sort_values(ascending = False)
sortAscRating
# Out:
# Precio Alto: "Happy Box" Cajas de Alitas y Snaks
# Precio Alto: 449.0
# Precio bajo: Lecaroz (QUERETARO)
# Precio bajo: 15.0
#      web-scraper-order                              web-scraper-start-url  \
# 0      1616630918-4119  https://www.ubereats.com/search?ps=1&q=pizza&p...
# 1      1616630918-4113  https://www.ubereats.com/search?ps=1&q=pizza&p...
# 2      1616630918-4107  https://www.ubereats.com/search?ps=1&q=pizza&p...
# 3      1616630918-4112  https://www.ubereats.com/search?ps=1&q=pizza&p...
# 4      1616630918-4102  https://www.ubereats.com/search?ps=1&q=pizza&p...
# ...                ...                                                ...
# 1349   1616628039-8075  https://www.rappi.com.mx/restaurantes/category...
# 1350   1616628032-7982  https://www.rappi.com.mx/restaurantes/category...
# 1351   1616628039-8072  https://www.rappi.com.mx/restaurantes/category...
# 1352   1616628097-8505  https://www.rappi.com.mx/restaurantes/category...
# ...

# %%
#Restaurantes por colonia
#el_pueblito dfPizzas_el_pueblito

sortAscPriceel_pueblito = dfPizzas_el_pueblito.sort_values(by = ['price-food'], ascending=False)
sortAscPriceel_pueblito.reset_index(drop=True, inplace=True)

print(f"Precio Alto: {sortAscPriceel_pueblito['name'][0]}")
print(f"Precio Alto: {sortAscPriceel_pueblito['price-food'][0]}")

preciosPorColoniasAltos.append(sortAscPriceel_pueblito['price-food'][0])

print(f"Precio bajo: {sortAscPriceel_pueblito['name'][len(sortAscPriceel_pueblito.index) - 1]}")
print(f"Precio bajo: {sortAscPriceel_pueblito['price-food'][len(sortAscPriceel_pueblito.index) - 1]}")

preciosPorColoniasBajos.append(sortAscPriceel_pueblito['price-food'][len(sortAscPriceel_pueblito.index) - 1])

sortAscRating = dfPizzas_el_pueblito.sort_values(by = ['rating'], ascending = False)
sortAscRating.reset_index(drop=True, inplace=True)

ratingPorColonia.append(sortAscRating['rating'])


duplicatesValuesel_pueblito = dfPizzas_el_pueblito.pivot_table(index = ['name-food'], aggfunc='size')

duplicatesValuesel_pueblito.sort_values(ascending = False)
sortAscPriceel_pueblito
# Out:
# Precio Alto: Emporio Pizza
# Precio Alto: 320.0
# Precio bajo: Mi Piace Pizza Qro
# Precio bajo: nan
#     web-scraper-order                              web-scraper-start-url  \
# 0     1616630946-1648  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 1     1616630946-1663  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 2     1616631153-2702  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 3     1616632599-7600  https://www.rappi.com.mx/restaurantes/category...
# 4     1616632609-7615  https://www.rappi.com.mx/restaurantes/category...
# ..                ...                                                ...
# 560   1616631191-2857  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 561   1616631032-2081  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 562   1616631102-2491  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# 563   1616631102-2503  https://www.ubereats.com/search?pl=JTdCJTIyYWR...
# ...

# %%
#Top 10
allRest = []

for i in tipicMenuCentro:
    allRest.append(i)
    
for i in tipicMenuAlamos:
    allRest.append(i)
    
for i in tipicMenuJuriquilla:
    allRest.append(i)

for i in tipicMenuMilenio:
    allRest.append(i)

for i in tipicMenurefugio:
    allRest.append(i)
    
for i in tipicMenubalvanera:
    allRest.append(i)
    
for i in tipicMenucampanario:
    allRest.append(i)
    
for i in tipicMenucerritocolorado:
    allRest.append(i)
    
for i in tipicMenucimatario:
    allRest.append(i)
    
for i in tipicMenuel_pueblito:
    allRest.append(i)

allRestAndRating = []

for i in allRest:
    if i not in allRestAndRating:
        k = df.loc[df['name'] == i]
        k.reset_index(drop=True, inplace=True)
        allRestAndRating.append(i)
        allRestAndRating.append(k['rating'][0])
    
restAndRating = []
import numpy
for i in range(0,len(allRestAndRating)-1,+2):
    k = i +1
    w = 0
    if not numpy.isnan(allRestAndRating[k]):
        w = allRestAndRating[k]
    aux = [allRestAndRating[i], w]
    restAndRating.append(aux)

for i  in range(len(restAndRating) - 1):
    for j in range(0, len(restAndRating) - i - 1):
        if restAndRating[j][1] < restAndRating[j+1][1]:
            restAndRating[j], restAndRating[j+1] = restAndRating[j+1], restAndRating[j]

rest = []
ratingRest = []
for i in range(11):
    if i != 2:
        rest.append(restAndRating[i][0])
        ratingRest.append(restAndRating[i][1])

        
plt.figure(figsize=(8, 8))
plt.barh(rest,ratingRest,color=['royalblue', 'g', 'r', 'c', 'm', 'y','sandybrown', 'hotpink', 'greenyellow' ,'deepskyblue'])
plt.title('Top 10 pizzerías de Qro')
plt.xlabel('Rating')
plt.ylabel('Pizzerias')
plt.show()

# %%
totDifRest = []

restaurantsOnCentro = dfPizzas_centro.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnCentro.sort_values(ascending = False)
len(restaurantsOnCentro)
#totDifRest.append(restaurantsOnCentro)
# Out:
# 102

# %%
restaurantsOnalamos = dfPizzas_alamos.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnalamos.sort_values(ascending = False)

len(restaurantsOnalamos)
#totDifRest.append(restaurantsOnalamos)
# Out:
# 82

# %%
restaurantsOnjuriquilla = dfPizzas_juriquilla.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnjuriquilla.sort_values(ascending = False)
len(restaurantsOnjuriquilla)
#totDifRest.append(restaurantsOnjuriquilla)
# Out:
# 56

# %%
restaurantsOnmilenio = dfPizzas_milenio.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnmilenio.sort_values(ascending = False)
len(restaurantsOnmilenio)
#totDifRest.append(restaurantsOnmilenio)
# Out:
# 93

# %%
restaurantsOnrefugio = dfPizzas_refugio.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnrefugio.sort_values(ascending = False)
len(restaurantsOnrefugio)
#totDifRest.append(restaurantsOnrefugio)
# Out:
# 23

# %%
restaurantsOnbalvanera = dfPizzas_balvanera.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnbalvanera.sort_values(ascending = False)
len(restaurantsOnbalvanera)
#totDifRest.append(restaurantsOnbalvanera)
# Out:
# 20

# %%
restaurantsOncampanario = dfPizzas_campanario.pivot_table(index = ['name'], aggfunc='size')
restaurantsOncampanario.sort_values(ascending = False)
len(restaurantsOncampanario)
#totDifRest.append(restaurantsOncampanario)
# Out:
# 54

# %%
restaurantsOncerritocolorado = dfPizzas_cerritocolorado.pivot_table(index = ['name'], aggfunc='size')
restaurantsOncerritocolorado.sort_values(ascending = False)
len(restaurantsOncerritocolorado)

#totDifRest.append(restaurantsOncerritocolorado)
# Out:
# 53

# %%
restaurantsOncimatario = dfPizzas_cimatario.pivot_table(index = ['name'], aggfunc='size')
restaurantsOncimatario.sort_values(ascending = False)
len(restaurantsOncimatario)
#totDifRest.append(restaurantsOncimatario)
# Out:
# 98

# %%
restaurantsOnel_pueblito = dfPizzas_el_pueblito.pivot_table(index = ['name'], aggfunc='size')
restaurantsOnel_pueblito.sort_values(ascending = False)
len(restaurantsOnel_pueblito)
#totDifRest.append(restaurantsOnel_pueblito)
# Out:
# 44

# %%
#print(len(totDifRest))
#print(totDifRest)

# %%
#preciosPorColoniasAltos

plt.figure(figsize=(8, 8))
plt.barh(colonies,preciosPorColoniasAltos,color=['royalblue', 'g', 'r', 'c', 'm', 'y','sandybrown', 'hotpink', 'greenyellow' ,'deepskyblue'])
plt.title('Precios más altos')
plt.xlabel('Precio')
plt.ylabel('Colonias')
plt.show()

# %%
preciosPorColoniasBajos = [15.0,15.0,26.0,25.0,39.9,69.0,25.0,15.0,15.0,28.0]

plt.figure(figsize=(8, 8))
plt.barh(colonies,preciosPorColoniasBajos,color=['royalblue', 'g', 'r', 'c', 'm', 'y','sandybrown', 'hotpink', 'greenyellow' ,'deepskyblue'])
plt.title('Precios más bajos')
plt.xlabel('Precio')
plt.ylabel('Colonias')
plt.show()

# %%
restaurantes = [102,82,56,93,23,20,54,53,98,44]
#plt.figure(figsize=(8, 8))
plt.barh(colonies,restaurantes,color=['royalblue', 'g', 'r', 'c', 'm', 'y','sandybrown', 'hotpink', 'greenyellow' ,'deepskyblue'])
plt.title('Restaurantes')
plt.xlabel('Número de restaurantes')
plt.ylabel('Colonia')
plt.show()
